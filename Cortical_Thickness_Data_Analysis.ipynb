# %%
import pandas as pd
CT_Data = pd.read_excel('Cortical_Thickness.xlsx')
CT_Data
# Out:
#      PTINDEX SCANINDEX        PTID  VISCODE  EXAMDATE DX_bl    DX   AGE  \
# 0          1   S108548  003_S_2374        0  20110613  EMCI  EMCI  81.3
# 1          1   S156236  003_S_2374       12  20120517  EMCI  EMCI  81.3
# 2          1   S266765  003_S_2374       24  20130726  EMCI  EMCI  81.3
# 3          2   S120805  003_S_4152        0  20110927    AD    AD  60.7
# 4          2   S142593  003_S_4152        3  20120210    AD    AD  60.7
# ..       ...       ...         ...      ...       ...   ...   ...   ...
# 807      212   S348128  129_S_4422       48  20160112    CN    CN  70.8
# 808      213   S185416  131_S_0123       84  20130321    CN  EMCI  73.3
# 809      213   S212285  131_S_0123       96  20140212    CN    AD  73.3
# 810      213   S250516  131_S_0123      108  20150303    CN    AD  73.3
# 811      213   S144552  131_S_0123       72  20120223    CN  EMCI  73.3
#
#     PTGENDER  PTEDUCAT  ... Node 139 Node 140 Node 141  Node 142  Node 143  \
# 0     Female        18  ...    1.782    2.402    1.492     1.987     1.724
# 1     Female        18  ...    1.821    2.121    1.517     2.119     1.862
# 2     Female        18  ...    1.787    2.354    1.557     1.951     1.840
# 3       Male        18  ...    1.900    2.156    1.751     1.802     1.704
# 4       Male        18  ...    1.912    2.161    1.757     1.906     2.103
# ..       ...       ...  ...      ...      ...      ...       ...       ...
# 807   Female        15  ...    1.823    2.606    1.828     2.088     2.077
# 808     Male        20  ...    1.711    2.225    1.716     1.952     1.897
# 809     Male        20  ...    1.756    2.406    1.703     1.847     1.799
# 810     Male        20  ...    1.751    2.601    1.639     1.925     1.839
# 811     Male        20  ...    1.717    2.289    1.717     1.983     1.821
#
#      Node 144  Node 145  Node 146  Node 147  Node 148
# 0       2.326     1.817     1.983     1.983     1.650
# 1       2.163     1.941     1.729     1.994     1.541
# 2       2.151     1.795     1.798     1.905     1.681
# 3       2.384     1.937     2.179     1.769     1.739
# 4       2.205     2.193     2.064     1.905     1.955
# ..        ...       ...       ...       ...       ...
# 807     2.556     1.890     2.010     1.969     1.860
# 808     2.444     1.855     2.304     2.097     1.543
# 809     2.130     1.876     2.108     2.032     1.577
# 810     2.256     1.949     1.880     2.085     1.571
# 811     1.492     1.893     2.178     2.100     1.720
#
# [812 rows x 162 columns]

# %%
Node_Data = CT_Data.iloc[:,14:]
Node_Data
# Out:
#      Node 1  Node 2  Node 3  Node 4  Node 5  Node 6  Node 7  Node 8  Node 9  \
# 0     1.978   2.037   2.073   2.172   2.197   2.314   2.359   2.245   2.656
# 1     1.914   1.912   2.086   2.243   2.179   2.352   2.357   2.164   2.652
# 2     1.880   1.934   2.148   2.103   2.373   2.248   2.312   2.260   2.542
# 3     2.054   2.333   2.148   2.498   2.467   2.526   2.339   2.329   2.505
# 4     2.046   2.370   2.165   2.481   2.381   2.509   2.360   2.233   2.534
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 807   2.047   2.215   2.000   2.310   2.384   2.699   2.354   2.404   2.959
# 808   2.000   2.191   1.897   2.427   2.386   2.539   2.404   2.265   2.685
# 809   2.107   2.041   1.963   2.522   2.410   2.665   2.543   2.352   2.514
# 810   2.062   2.007   1.939   2.638   2.441   2.605   2.452   2.453   2.641
# 811   2.044   2.136   1.914   2.599   2.477   2.537   2.460   2.359   2.640
#
#      Node 10  ...  Node 139  Node 140  Node 141  Node 142  Node 143  Node 144  \
# 0      2.067  ...     1.782     2.402     1.492     1.987     1.724     2.326
# 1      1.776  ...     1.821     2.121     1.517     2.119     1.862     2.163
# 2      1.631  ...     1.787     2.354     1.557     1.951     1.840     2.151
# 3      2.750  ...     1.900     2.156     1.751     1.802     1.704     2.384
# 4      2.674  ...     1.912     2.161     1.757     1.906     2.103     2.205
# ..       ...  ...       ...       ...       ...       ...       ...       ...
# 807    2.062  ...     1.823     2.606     1.828     2.088     2.077     2.556
# 808    1.978  ...     1.711     2.225     1.716     1.952     1.897     2.444
# 809    1.946  ...     1.756     2.406     1.703     1.847     1.799     2.130
# 810    1.863  ...     1.751     2.601     1.639     1.925     1.839     2.256
# 811    1.901  ...     1.717     2.289     1.717     1.983     1.821     1.492
#
#      Node 145  Node 146  Node 147  Node 148
# 0       1.817     1.983     1.983     1.650
# 1       1.941     1.729     1.994     1.541
# 2       1.795     1.798     1.905     1.681
# 3       1.937     2.179     1.769     1.739
# 4       2.193     2.064     1.905     1.955
# ..        ...       ...       ...       ...
# 807     1.890     2.010     1.969     1.860
# 808     1.855     2.304     2.097     1.543
# 809     1.876     2.108     2.032     1.577
# 810     1.949     1.880     2.085     1.571
# 811     1.893     2.178     2.100     1.720
#
# [812 rows x 148 columns]

# %%
Y_Data = CT_Data['DX']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components= 20)

principalComponents = pca.fit_transform(Node_Data)
                                        
principalDf = pd.DataFrame(data = principalComponents)

# %%
explained_variance = pca.explained_variance_ratio_

sum = 0
seventy_five_percent = []

for i in range(len(explained_variance)):
    sum += explained_variance[i]
    if (sum > 0.75):
        break
        
seventy_five_percent = explained_variance[0:i]

print(seventy_five_percent)
# Out:
# [0.24127784 0.06214447 0.04736645 0.0306382  0.02697529 0.02579522
#  0.02418149 0.0210673  0.0195892  0.01777799 0.01746557 0.01613407
#  0.01515497 0.01438309 0.01335019 0.01321986 0.01246212 0.01199999
#  0.0113343 ]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

x=[]
count = 0

for i in range(len(explained_variance)):
    count += 1
    x.append(count)

y = explained_variance
ax.bar(x,y)
plt.show()
plt.savefig('CT_PCA_Components.eps')

# %%
from sklearn.cluster import KMeans

# calculate distortion for a range of number of cluster
distortions = []
for i in range(1, 11):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(Node_Data)
    distortions.append(km.inertia_)

# plot
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()
plt.savefig('CT_Elbow_Test_For_K_Means.eps')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(dict(PC1=principalDf.iloc[:,0], PC2=principalDf.iloc[:,1], color = Y_Data))

sns.lmplot('PC1', 'PC2', data=df, hue='color', fit_reg=False)

plt.show()

plt.savefig('CT_2_Component_Clustering.eps')

# %%
for i in range(len(df.color)):
    
    if (df.color[i] == 'AD' or df.color[i] == 'LMCI' or df.color[i] == 'EMCI'):
        df.color[i] = 'AD, LMCI, or EMCI'
    else:
        df.color[i] = 'CN or SMC'
    
df.color
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0      AD, LMCI, or EMCI
# 1      AD, LMCI, or EMCI
# 2      AD, LMCI, or EMCI
# 3      AD, LMCI, or EMCI
# 4      AD, LMCI, or EMCI
#              ...
# 807            CN or SMC
# 808    AD, LMCI, or EMCI
# 809    AD, LMCI, or EMCI
# 810    AD, LMCI, or EMCI
# 811    AD, LMCI, or EMCI
# Name: color, Length: 812, dtype: object

# %%
sns.lmplot('PC1', 'PC2', data=df, hue='color', fit_reg=False)

plt.show()

plt.savefig('CT_2_Component_Clustering_2_Color.eps')

# %%
X_train = Node_Data.iloc[0:650,:]

Y_train = Y_Data.iloc[0:650]

X_test = Node_Data.iloc[650:,:]

Y_test = Y_Data.iloc[650:]


from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

clf.fit(X_train, Y_train)

Y_pred = clf.predict(X_test)

from sklearn import metrics

print ("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.3950617283950617

# %%
## Random Forest Using Data after PCA

X_train = principalDf.iloc[0:650,:]

Y_train = Y_Data.iloc[0:650]

X_test = principalDf.iloc[650:,:]

Y_test = Y_Data.iloc[650:]


from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

clf.fit(X_train, Y_train)

Y_pred = clf.predict(X_test)

from sklearn import metrics

print ("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.3271604938271605

# %%
from sklearn.model_selection import cross_val_score
from sklearn import svm

clf = svm.SVC(kernel = 'linear', C = 1)
scores = cross_val_score(clf, principalDf, Y_Data, cv=5)
scores
# Out:
# array([0.38650307, 0.38650307, 0.37654321, 0.2962963 , 0.44444444])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.38 (+/- 0.09)

# %%
from sklearn.model_selection import cross_val_score
from sklearn import svm

clf = svm.SVC(kernel = 'linear', C = 6)
scores = cross_val_score(clf, principalDf, df.color, cv=5)
print (scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.71165644 0.70552147 0.64814815 0.68518519 0.70987654]
# Accuracy: 0.69 (+/- 0.05)

# %%
linear regression
